# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def FTS(T):    
    #return np.fft.fftshift( np.fft.fft(np.fft.fftshift(T)) )
    return np.fft.fftshift( np.fft.fft(np.fft.fftshift(T)) )
    #return np.fft.fft(T) 

def iFTS(T):
    return np.fft.ifftshift( np.fft.ifft(np.fft.ifftshift(T)) )    
    #return np.fft.ifft(T) 

def plh(dz, kz, r, T, lam, dx):
    """
    frensel impulse response propagation
    
    kz - фазовая маска
    T - поле, с которым производится операция """
    
    if (lam*dz/(T.shape[0]*dx**2)) < 0.3:
        f = iFTS( FTS(T)*(np.exp(1j*kz*dz)) )
        
    else:
        k = 2*np.pi/lam
        #fh = 1/(1j*lam*dz)*np.exp(1j*k*(r**2)/2/dz)
        fh = np.exp(1j*k*(r**2)/2/dz)
        fh = FTS(fh) #нормировка        
        f = iFTS( FTS(T)*fh )
    return f

def rphase(dx,L,k):
    kx = np.arange(-1/(2*dx), 1/(2*dx), 1/L)
    
    kz = 2*np.pi*np.sqrt((k/(2*np.pi))**2-kx**2)
    return kz

def Lens(x, k, focus):
    r2 = x**2
    return  k*r2/(2*focus)

def circ(r,a):
    return np.abs(r) < a

# %% [markdown]
# class sct_object:
#     aspx = 128 #number of pixels in A-scan
#     lam  = .85 #All in mcm
#     Xmax = 256
#     zs   = 200
#
#     def __init__(self,K):
#         self.K = K #List scatterers coordinates
#     def Ascan():

# %%
l = 512
K = np.zeros(l)
K[256] = 1

zs = .2

kx = np.arange(-1/(2*dx), 1/(2*dx), 1/L)
UL = ( np.exp(-r**2/2/sig**2)*np.exp(-1j*r**3 )).astype(complex)
kz = 2*np.pi*np.sqrt((k/(2*np.pi))**2-kx**2)
h  = np.exp(1j*kz*zs)
Bs = K*( iFTS(FTS(UL)*h) )**2

# %%
plt.plot(np.abs((iFTS(FTS(UL)*h)))**2)

# %%
l = 512
K = np.zeros(l,dtype=complex)
K[256] = 1
aspx = 128
dx = 0.53
L  = dx*l
zs = 100
focus = 100
B = np.zeros((aspx,l),dtype=complex)

kx = np.arange(-1/(2*dx), 1/(2*dx), 1/L)
lam = .85
k = 2*np.pi/lam

spec_wight = .07 #70 nm 
Spec = np.arange(lam-spec_wight/2,lam+spec_wight/2
                 -spec_wight/aspx,spec_wight/aspx)
Spec = 2*np.pi/Spec
A = np.zeros(aspx,dtype=complex)

x = np.arange(-L/2, L/2, dx)

for j,x0 in enumerate(x):
    r  =  np.abs(x - x0)
    r2 = r**2
    UL = ( ( np.exp(-r2/2/sig**2) ).astype(complex)
          *np.exp(-1j*k*r2/(2*focus))*circ(r,40) )#*np.exp( -1j*r**1.5 )
    fUL = FTS(UL)
    
    for i,k in enumerate(Spec):
        kz = 2*np.pi*np.sqrt((k/(2*np.pi))**2-kx**2)
        h  = np.exp(1j*kz*zs)*np.exp(i)
        A[i] = (K*( iFTS(fUL*h) )**2).sum()
    B[:,j] = iFTS(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9883c69cf89f> in <module>
#      25     r2 = r**2
#      26     UL = ( ( np.exp(-r2/2/sig**2) ).astype(complex)
# ---> 27           *np.exp(-1j*k*r2/(2*focus))*circ(r,40) )#*np.exp( -1j*r**1.5 )
#      28     fUL = FTS(UL)
#      29
#
# NameError: name 'sig' is not defined

# %%
dz = .2
fh = np.exp(1j*k/(2*dz)*r**2 )#/(1j*lam*dz)
fh = FTS(fh)/UL.shape[0] #Очеь странно, конечно -(
f1 = iFTS( FTS(UL)*fh )

f2 = iFTS( FTS(UL)*(np.exp(1j*kz*dz)) )

fig, axes = plt.subplots(nrows=1,ncols=2, figsize=(15,5))
axes[0].plot(np.abs(f1))
axes[0].set_title('Impulse response')
axes[1].plot(np.abs(f2))
axes[1].set_title('Amplitude trasfer function')
print( np.abs(f2).max()/np.abs(f1).max() )

# %% [markdown]
# <h2>Generate right $U_S$ </h2>
#
# For lens sampling the relation for pixel size mast be fulfilled: $ dx \leq \frac{f}{2D}\lambda $

# %%
L/2
# Out:
# 135.68

# %%
lam = .85
dx = 0.53
l  = 512
L  = dx*l
k  = 2*np.pi/lam
x = np.arange(-L/2, L/2, dx)
fok = 200.

kz = rphase(dx,L,k)
r = np.abs(x)

ra = 40 #Aperture radius
sig = 1/np.sqrt(2)*ra

UL = np.exp(-r**2/2/sig**2).astype(complex)
fok = 200
UL *= np.exp(-1j*Lens(x,k,fok))*circ(r,40)
plt.plot(np.abs(UL))
print( 'dx mmust be less then {:.2f} mcm'.format(fok*lam/(2*(2*ra*2))) )
# Out:
# dx mmust be less then 0.53 mcm

# %%
plt.plot(x)

# %%
B = np.zeros((128,l), dtype=complex)
dz = 2
for zx in range(0,128):
    B[zx,:] = plh(zx*dz,kz,r,UL,lam,dx)

fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(15,5))
axes[0].imshow(np.abs(B[55:,200:312]))
axes[0].set_xlabel('x');
axes[0].set_ylabel('z');
axes[0].set_title('Field in XZ plane');

axes[1].plot(np.abs(B[100,200:312]))
axes[1].set_xlabel('x')
axes[1].set_title('Intensity in focus')
# Out:
# Text(0.5, 1.0, 'Intensity in focus')

# %%
np.abs(B).max()

# %% [markdown]
# <h2> Check equations from article  </h2>
#
# Calculate field $U_s$ from eq. 3.
#
# $$U_s(x_0)=\int g(k_x)h(k_x)e^{ ik_x(x_s-x_0) }dk_x=FT\big(F(k_x)e^{ik_xx_s} \big) $$

# %%
kx = np.arange(-1/(2), 1/(2), 1/l)

# %%
scl
# Out:
# 0.04419417382415922

# %%
#kx = np.arange(-1/(2*dx), 1/(2*dx), 1/L)
kx = np.arange(-1/(2), 1/(2), 1/l)
xs = 2
scl = np.sqrt(1/UL.shape[0]) #Scale
zs = fok
g = scl*FTS(UL);
h = (np.exp(1j*kz*zs))
Us = FTS(g*h*np.exp(1j*kx*xs))

B1 = np.zeros((128,l), dtype=complex)
dz = 2

for zx in range(0,128):
    zs = zx*dz
    h = (np.exp(1j*kz*zs))
    B1[zx,:] = FTS(g*h*np.exp(1j*kx*xs))

fig, axes = plt.subplots(nrows=2,ncols=2,figsize=(15,5))
axes = axes.flatten()
    
axes[0].imshow(np.abs(B1[65:,200:312]))
axes[0].set_xlabel('x');
axes[0].set_ylabel('z');
axes[0].set_title('Field in XZ plane');

axes[1].plot(np.abs(B1[100,200:312]))
axes[1].set_xlabel('x')
axes[1].set_title('Intensity in focus')

axes[2].imshow( np.abs(Btemp[65:,200:312]) ) #Field with paramiter xs=0
axes[3].plot(np.abs(Btemp[100,200:312]))

print(np.abs(Btemp[100,200:312]).argmax(),' / ',np.abs(B1[100,200:312]).argmax())
# Out:
# 56  /  56

# %%
(91-54)/72

# %%
S = np.zeros(512) #Scattering object
S[256] = 1

xs = 0

g = scl*FTS(UL);
h = (np.exp(1j*kz*zs))
Us = FTS(g*h*np.exp(1j*kx*xs))
UsK = S*Us

plt.plot(np.abs(UsK))

# %%
print((xs.imag))
